# !wget https://lh3.googleusercontent.com/pw/AM-JKLUuFw1rf-advU7KPSnFax97-BXEhG3H6ty7MFemCrGy_qYDXvDkV2dvTMvLcZTQj44gm9xTVD6wRsIp9Z--TACrq8w8v53hcHO2OwV7cYNzkqtSo6dSbOCrpPpZiBhC8gIb_1Z9H_IuvqTSoVNphNY=w640-h1378-no?authuser=0 -O unknown/face2.jpg
# !wget https://lh3.googleusercontent.com/pw/AM-JKLVRdXzKEiPkYcgdtJKmwkm8BvdKspWrrmNapJM4oin7S_1pMm0gEuvv2cyQ67CUDhQCDvsK41WAZPx3ODUMrf52Ph7uEUiFh55OrBgMnZCzckzMbELDe81OK-nDDoxqwZY0H4hbq8FKumIU15ufnrc=w960-h1280-no?authuser=0 -O unknown/face3.jpg
# !wget https://lh3.googleusercontent.com/pw/AM-JKLWLHFQKA5WEK1OtO4FiKegpuB2gO4ybH1ajHQXDAo3Ob-b36SwnZxfm1_wkWMmngCw90NcLYnAECxaXMMHQrI21ae6UJqP3Mla2ZVFdNl3l6Uh6bm55XRX0tqHFbmmCWg-9-xT5CGhM7cD4_nvlq9c=w959-h1279-no?authuser=0 -O unknown/face4.jpg
# !wget https://lh3.googleusercontent.com/pw/AM-JKLX9BRUC6ee0bgTbNHp7OlBwMBaqi2gNjlxtDUXLRzHN-939EzE7Cdb2qLiFaYmAXBaJVN8AU9pxVfr4gyOyb7MCLpakKkGq0yDFhgcUzQex74S3H7uudDgUI9G_MnLCYcAmWBvmeGePh8Voab2RWXg=w776-h1378-no?authuser=0 -O unknown/face5.jpg
# !wget https://lh3.googleusercontent.com/pw/AM-JKLUtAmT1u63fckVYMm6WSxEQ5CPYC3GCKQCPnByskTtbgOb5eREY15XHnUbGQ8p8IX0nD6eUDnMwpzkJBbyv_OtPGgPTRp2PUskxb-lqXFeThJLBnaehgqT6HdgQTWkP_LTt74qZ4vFHR3UDg65Weg8=w1034-h1378-no?authuser=0 -O unknown/face6.jpg
# Out:
# mkdir: cannot create directory ‘unknown’: File exists
# --2021-10-11 05:51:59--  https://lh3.googleusercontent.com/pw/AM-JKLW3o26DQzdFdgCFCilp88p8i5OUPIyfyVNsblTp0z5l4Wcw5MTUIbJa-oAvkM_P0pMN7B0YkRhACvfqxh2h7FE5lb2Cg03eJfHa0FsMLMAJVuyg-D4P8RRC4g7deRNrRvsH2yzHFuu-aWdXPJHKxmc=w1034-h1378-no?authuser=0
# Resolving lh3.googleusercontent.com (lh3.googleusercontent.com)... 142.251.6.132, 2607:f8b0:4001:c5a::84
# Connecting to lh3.googleusercontent.com (lh3.googleusercontent.com)|142.251.6.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 165325 (161K) [image/jpeg]
# Saving to: ‘unknown/face1.jpg’
#
# unknown/face1.jpg   100%[===================>] 161.45K  --.-KB/s    in 0.004s
#
# 2021-10-11 05:51:59 (36.1 MB/s) - ‘unknown/face1.jpg’ saved [165325/165325]

# %%
import face_recognition
import cv2
import os
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('known/Pranav_Taneja.jpg')

# %%
print(img)
img.shape
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [152 158 165]
#   [151 157 164]
#   [156 160 161]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [219 225 232]
#   [219 225 232]
#   [224 228 229]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [246 250 255]
#   [246 250 255]
#   [246 250 251]]
#
#  ...
#
#  [[ 11  10 174]
#   [  9  11 173]
#   [  9  11 173]
#   ...
#   [109  66  51]
#   [109  66  51]
#   [111  65  54]]
#
#  [[ 11   9 175]
#   [ 11  10 174]
#   [ 11  10 174]
#   ...
#   [107  64  55]
#   [107  65  53]
#   [111  65  54]]
#
#  [[ 15   8 177]
#   [ 13   9 175]
#   [ 12   8 174]
#   ...
#   [105  63  58]
#   [107  63  56]
#   [111  65  54]]]
# (371, 273, 3)

# %%
def read_img(pat):
  img = cv2.imread(pat)
  (h, w) = img.shape[:2]
  width = 500
  ratio = width / w
  height = int (h * ratio)
  return cv2.resize(img, (width, height))

# %%
img_enc = face_recognition.face_encodings(img)[0]
img_enc.shape
# Out:
# (128,)

# %%
known_encodings = [];
known_names = [];
known_dir = 'known'
print(os.listdir(known_dir))
for file in os.listdir(known_dir):
  # print(file)
  if file != '.ipynb_checkpoints':
      img = read_img(known_dir + '/' + file)
      img_enc = face_recognition.face_encodings(img)[0]
      known_encodings.append(img_enc)
      known_names.append(file.split('.')[0])
print(known_names)
# Out:
# ['Pranav_Taneja.jpg', 'Pranav_Mittal.jpg', 'Prakash_Narayan_Budhaulia.jpg', 'Priyanshu_Nailwal.jpg']
# ['Pranav_Taneja', 'Pranav_Mittal', 'Prakash_Narayan_Budhaulia', 'Priyanshu_Nailwal']

# %%
unknown_dir = 'unknown'
for file in os.listdir(unknown_dir):
  if file != '.ipynb_checkpoints':
    print('Processing', file)
    img = read_img(unknown_dir + '/' + file)
    img_enc = face_recognition.face_encodings(img)[0]
    res = face_recognition.compare_faces(known_encodings, img_enc)

    for (i, r) in enumerate(res):
      if(r):
        name = known_names[i]
        print(name);
        (top, right, bottom, left) = face_recognition.face_locations(img)[0]
        cv2.rectangle(img, (left, top), (right, bottom), (0, 0, 255), 2)
        cv2.putText(img, name, (left+2, bottom+20), cv2.FONT_HERSHEY_PLAIN, 2, (0, 0, 255), 2)
        cv2_imshow(img)
        break;
# Out:
# Processing face3.jpg
# Prakash_Narayan_Budhaulia
# <PIL.Image.Image image mode=RGB size=500x666 at 0x7F01F514DD90>
# Processing face1.jpg
# Pranav_Mittal
# <PIL.Image.Image image mode=RGB size=500x666 at 0x7F020C0F47D0>
# Processing face2.jpg
# Pranav_Mittal
# <PIL.Image.Image image mode=RGB size=500x1078 at 0x7F01F6272590>
# Processing face4.jpg
# Priyanshu_Nailwal
# <PIL.Image.Image image mode=RGB size=500x666 at 0x7F020C0F47D0>
# Processing face5.jpg
# Pranav_Taneja
# <PIL.Image.Image image mode=RGB size=500x889 at 0x7F01F511A0D0>
# Processing face6.jpg
# Pranav_Taneja
# <PIL.Image.Image image mode=RGB size=500x666 at 0x7F01F511A0D0>
